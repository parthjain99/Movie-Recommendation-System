# %%
from tensorflow.keras.layers import Dense, Embedding, Input, Flatten, Multiply, Concatenate
from tensorflow.keras.regularizers import l2
from tensorflow.keras import Model
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.models import load_model
from tensorflow.keras.initializers import RandomNormal

from sklearn.metrics import mean_squared_error
from sklearn.metrics import ndcg_score

from recommenders.datasets import movielens
from recommenders.datasets.python_splitters import python_chrono_split
import pandas as pd
import numpy as np

# %%
data = movielens.load_pandas_df(size='1m')
# Out:
# 100%|█████████████████████████████████████████████████████████████████| 5.78k/5.78k [00:00<00:00, 18.6kKB/s]

# %%
train_data, test_data = python_chrono_split(data, 0.8)

# %%
train_data.columns = ['user_id','product_id','rating','timestamp']
test_data.columns = ['user_id','product_id','rating','timestamp']

# %%
def build_model(num_users, num_items, mf_output_dim,
          embeddings_init, reg_parameter=0, layers=[10],
          user_weights=None, product_weights=None):

    user_input = Input((1,), dtype='int64',name='user_input')
    product_input = Input((1,), dtype= 'int64',name='product_input')

    if user_weights and product_weights:
        mf_user_embeddings = Embedding(num_users, mf_output_dim, input_length=1, weights=[user_weights],
                                       embeddings_regularizer=l2(reg_parameter))
        mf_product_embeddings = Embedding(num_items, mf_output_dim, input_length=1, weights=[product_weights],
                                          embeddings_regularizer=l2(reg_parameter))

        mlp_user_embeddings = Embedding(num_users, mf_output_dim, input_length=1, weights=[user_weights],
                                       embeddings_regularizer=l2(reg_parameter))
        mlp_product_embeddings = Embedding(num_items, mf_output_dim, input_length=1, weights=[product_weights],
                                          embeddings_regularizer=l2(reg_parameter))



    else:
        mf_user_embeddings = Embedding(num_users, mf_output_dim, input_length=1,
                                       embeddings_initializer = embeddings_init, embeddings_regularizer=l2(reg_parameter))
        mf_product_embeddings = Embedding(num_items, mf_output_dim, input_length=1,
                                          embeddings_initializer = embeddings_init, embeddings_regularizer=l2(reg_parameter))

        mlp_user_embeddings = Embedding(num_users, mf_output_dim, input_length=1,embeddings_initializer=embeddings_init,
                                        embeddings_regularizer=l2(reg_parameter))
        mlp_product_embeddings = Embedding(num_items, mf_output_dim, input_length=1,embeddings_initializer=embeddings_init,
                                          embeddings_regularizer=l2(reg_parameter))


    ## Matrix Factorisation
    mf_user_latent = Flatten()(mf_user_embeddings(user_input))
    mf_product_latent = Flatten()(mf_product_embeddings(product_input))

    mf_latent = Multiply()([mf_user_latent, mf_product_latent])


    ## MLP
    mlp_user_latent = Flatten()(mlp_user_embeddings(user_input))
    mlp_product_latent = Flatten()(mlp_product_embeddings(product_input))

    mlp_latent = Concatenate()([mlp_user_latent, mlp_product_latent])

    for i in range(1, len(layers)):
        layer = Dense(layers[i], activation='relu', kernel_regularizer = l2(reg_parameter))
        mlp_latent = layer(mlp_latent)

    final_vector = Concatenate()([mf_latent, mlp_latent])

    prediction = Dense(1, activation='linear')(final_vector)

    model = Model(inputs=[user_input, product_input], outputs=prediction)
    return model

# %%
unique_prods = set(pd.concat([train_data['product_id'],test_data['product_id']]))

# %%
user2id = {v:k for k,v in enumerate(train_data['user_id'].unique())}
id2user = {v:k for k,v in user2id.items()}

prod2id = {v:k for k,v in enumerate(unique_prods)}
id2prod = {v:k for k,v in prod2id.items()}

# %%
max(id2prod.keys())
# Out:
# 3705

# %%
len(user2id), len(prod2id)
# Out:
# (6040, 3706)

# %%
train_data['new_user_id'] = train_data['user_id'].apply(lambda x : user2id[x])
test_data['new_user_id'] = test_data['user_id'].apply(lambda x : user2id[x])

# %%
train_data['new_prod_id'] = train_data['product_id'].apply(lambda x : prod2id[x])
test_data['new_prod_id'] = test_data['product_id'].apply(lambda x : prod2id[x])

# %%
train_data['rating'] = train_data['rating'].apply(lambda x : float(x))

# %%
test_users = test_data['new_user_id'].values
test_products = test_data['new_prod_id'].values

# %%
users = train_data['new_user_id'].values
products = train_data['new_prod_id'].values
ratings = train_data['rating'].values

# %%
def calculate_metrics(user_df, top_k=10, threshold=4):
    
    user_df = user_df.sort_values(by='predictions', ascending=False)
    
    true_relevant = (user_df['rating'] >= threshold).sum()
    recommended = (user_df['predictions'][:top_k] >= threshold).sum()
    
    numerator = sum((true>=4) and (pred>=4) for (true,pred) in zip(user_df['rating'][:top_k], user_df['predictions'][:top_k]))
    
    prec = numerator / recommended if recommended>0 else 0
    recall = numerator / true_relevant if true_relevant>0 else 0
    
    ndcg = ndcg_score([user_df['rating'].values], [user_df['predictions'].values], k=top_k)
    
    return pd.Series({'precision':prec,'recall':recall,'ndcg':ndcg})

# %%
embeddings_factor = [8,16,32,64,100]
n_layers = [128],[128,64], [128,64,32]
output_dir = 'models/'

metrics_list = []
for output_dim in embeddings_factor:
    for layer in n_layers:
        model = build_model(len(user2id),len(prod2id),output_dim, RandomNormal(0,0.01),reg_parameter=0.01,layers=layer)
        model.compile('adam',loss=MeanSquaredError(), metrics = [RootMeanSquaredError()])
        
        checkpoint_path = output_dir + "emb_" + str(output_dim) + "/" + str(len(layer))
        checkpoint = ModelCheckpoint(checkpoint_path + "/model.h5",save_best_only=True, save_weights_only=False)
        model.fit(x=[users,products], y=ratings,shuffle = True, validation_split=0.1, batch_size=256, epochs=15, callbacks=[checkpoint])
        
        preds = model.predict([test_users, test_products])
        test_data['predictions'] = preds
        metrics = test_data.groupby(['user_id']).apply(calculate_metrics)
        rmse = np.sqrt(mean_squared_error(test_data['rating'], test_data['predictions']))
        avg_prec = metrics['precision'].mean()
        avg_recall = metrics['recall'].mean()
        avg_ndcg = metrics['ndcg'].mean()
        
        metrics_list.append([output_dim, len(layer),rmse, avg_prec, avg_recall, avg_ndcg])
# Out:
# 2022-04-25 17:09:22.129900: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-04-25 17:09:27.361302: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9575 MB memory:  -> device: 0, name: NVIDIA RTX A4000, pci bus id: 0000:05:00.0, compute capability: 8.6
# 2022-04-25 17:09:27.362943: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 3652 MB memory:  -> device: 1, name: NVIDIA RTX A4000, pci bus id: 0000:08:00.0, compute capability: 8.6
# 2022-04-25 17:09:27.364201: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 102 MB memory:  -> device: 2, name: NVIDIA RTX A4000, pci bus id: 0000:09:00.0, compute capability: 8.6
# 2022-04-25 17:09:27.365410: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:3 with 88 MB memory:  -> device: 3, name: NVIDIA RTX A4000, pci bus id: 0000:84:00.0, compute capability: 8.6
# Epoch 1/15
#   29/2814 [..............................] - ETA: 17s - loss: 14.0179 - root_mean_squared_error: 3.7376
# 2022-04-25 17:09:30.975554: I tensorflow/stream_executor/cuda/cuda_blas.cc:1786] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2814/2814 [==============================] - 23s 7ms/step - loss: 4.4891 - root_mean_squared_error: 1.7880 - val_loss: 2.4987 - val_root_mean_squared_error: 1.3412
# Epoch 2/15
# 2814/2814 [==============================] - 20s 7ms/step - loss: 1.3577 - root_mean_squared_error: 0.9997 - val_loss: 1.2445 - val_root_mean_squared_error: 1.0377
# Epoch 3/15
# 2814/2814 [==============================] - 20s 7ms/step - loss: 1.0267 - root_mean_squared_error: 0.9529 - val_loss: 1.1298 - val_root_mean_squared_error: 1.0139
# Epoch 4/15
# 2814/2814 [==============================] - 16s 6ms/step - loss: 1.0031 - root_mean_squared_error: 0.9516 - val_loss: 1.1205 - val_root_mean_squared_error: 1.0126
# Epoch 5/15
# 2814/2814 [==============================] - 20s 7ms/step - loss: 0.9989 - root_mean_squared_error: 0.9517 - val_loss: 1.1200 - val_root_mean_squared_error: 1.0132
# Epoch 6/15
# 2814/2814 [==============================] - 20s 7ms/step - loss: 0.9965 - root_mean_squared_error: 0.9516 - val_loss: 1.1188 - val_root_mean_squared_error: 1.0136
# Epoch 7/15
# 2814/2814 [==============================] - 20s 7ms/step - loss: 0.9932 - root_mean_squared_error: 0.9504 - val_loss: 1.1148 - val_root_mean_squared_error: 1.0134
# Epoch 8/15
# 2814/2814 [==============================] - 17s 6ms/step - loss: 0.9879 - root_mean_squared_error: 0.9486 - val_loss: 1.1071 - val_root_mean_squared_error: 1.0104
# Epoch 9/15
# 2814/2814 [==============================] - 19s 7ms/step - loss: 0.9771 - root_mean_squared_error: 0.9453 - val_loss: 1.1030 - val_root_mean_squared_error: 1.0110
# Epoch 10/15
# 2814/2814 [==============================] - 20s 7ms/step - loss: 0.9667 - root_mean_squared_error: 0.9421 - val_loss: 1.0979 - val_root_mean_squared_error: 1.0107
# Epoch 11/15
# 2814/2814 [==============================] - 20s 7ms/step - loss: 0.9527 - root_mean_squared_error: 0.9379 - val_loss: 1.0868 - val_root_mean_squared_error: 1.0079
# Epoch 12/15
# 2814/2814 [==============================] - 18s 6ms/step - loss: 0.9412 - root_mean_squared_error: 0.9347 - val_loss: 1.0774 - val_root_mean_squared_error: 1.0062
# Epoch 13/15
# 2814/2814 [==============================] - 18s 6ms/step - loss: 0.9337 - root_mean_squared_error: 0.9331 - val_loss: 1.0742 - val_root_mean_squared_error: 1.0063
# Epoch 14/15
# 2814/2814 [==============================] - 19s 7ms/step - loss: 0.9292 - root_mean_squared_error: 0.9320 - val_loss: 1.0641 - val_root_mean_squared_error: 1.0032
# Epoch 15/15
# 2814/2814 [==============================] - 19s 7ms/step - loss: 0.9249 - root_mean_squared_error: 0.9310 - val_loss: 1.0656 - val_root_mean_squared_error: 1.0046
# Epoch 1/15
# 2814/2814 [==============================] - 21s 7ms/step - loss: 1.5425 - root_mean_squared_error: 1.1398 - val_loss: 1.2083 - val_root_mean_squared_error: 1.0230
# Epoch 2/15
# 2814/2814 [==============================] - 21s 7ms/step - loss: 1.0638 - root_mean_squared_error: 0.9557 - val_loss: 1.1604 - val_root_mean_squared_error: 1.0133
# Epoch 3/15
# 2814/2814 [==============================] - 21s 7ms/step - loss: 1.0075 - root_mean_squared_error: 0.9413 - val_loss: 1.1194 - val_root_mean_squared_error: 1.0052
# Epoch 4/15
# 2814/2814 [==============================] - 17s 6ms/step - loss: 0.9738 - root_mean_squared_error: 0.9323 - val_loss: 1.1005 - val_root_mean_squared_error: 1.0016
# Epoch 5/15
# 2814/2814 [==============================] - 21s 7ms/step - loss: 0.9603 - root_mean_squared_error: 0.9294 - val_loss: 1.0978 - val_root_mean_squared_error: 1.0022
# Epoch 6/15
# 2814/2814 [==============================] - 21s 7ms/step - loss: 0.9548 - root_mean_squared_error: 0.9289 - val_loss: 1.1032 - val_root_mean_squared_error: 1.0072
# Epoch 7/15
# 2814/2814 [==============================] - 22s 8ms/step - loss: 0.9510 - root_mean_squared_error: 0.9286 - val_loss: 1.0957 - val_root_mean_squared_error: 1.0036
# Epoch 8/15
# 2814/2814 [==============================] - 20s 7ms/step - loss: 0.9491 - root_mean_squared_error: 0.9289 - val_loss: 1.0884 - val_root_mean_squared_error: 1.0009
# Epoch 9/15
# 2814/2814 [==============================] - 22s 8ms/step - loss: 0.9465 - root_mean_squared_error: 0.9286 - val_loss: 1.0810 - val_root_mean_squared_error: 1.0003
# Epoch 10/15
# 2814/2814 [==============================] - 23s 8ms/step - loss: 0.9444 - root_mean_squared_error: 0.9284 - val_loss: 1.0850 - val_root_mean_squared_error: 1.0016
# Epoch 11/15
# 2814/2814 [==============================] - 24s 8ms/step - loss: 0.9446 - root_mean_squared_error: 0.9287 - val_loss: 1.0939 - val_root_mean_squared_error: 1.0037
# Epoch 12/15
# 2814/2814 [==============================] - 24s 8ms/step - loss: 0.9428 - root_mean_squared_error: 0.9285 - val_loss: 1.0855 - val_root_mean_squared_error: 1.0004
# Epoch 13/15
# 2814/2814 [==============================] - 24s 8ms/step - loss: 0.9433 - root_mean_squared_error: 0.9287 - val_loss: 1.0801 - val_root_mean_squared_error: 1.0010
# Epoch 14/15
# 2814/2814 [==============================] - 23s 8ms/step - loss: 0.9423 - root_mean_squared_error: 0.9289 - val_loss: 1.0896 - val_root_mean_squared_error: 1.0055
# Epoch 15/15
# 2814/2814 [==============================] - 20s 7ms/step - loss: 0.9409 - root_mean_squared_error: 0.9286 - val_loss: 1.0969 - val_root_mean_squared_error: 1.0089
# Epoch 1/15
# 2814/2814 [==============================] - 25s 8ms/step - loss: 1.4210 - root_mean_squared_error: 1.0776 - val_loss: 1.2185 - val_root_mean_squared_error: 1.0159
# Epoch 2/15
# 2814/2814 [==============================] - 22s 8ms/step - loss: 1.0777 - root_mean_squared_error: 0.9514 - val_loss: 1.1826 - val_root_mean_squared_error: 1.0121
# Epoch 3/15
# 2814/2814 [==============================] - 22s 8ms/step - loss: 1.0332 - root_mean_squared_error: 0.9411 - val_loss: 1.1650 - val_root_mean_squared_error: 1.0137
# Epoch 4/15
# 2814/2814 [==============================] - 22s 8ms/step - loss: 1.0014 - root_mean_squared_error: 0.9327 - val_loss: 1.1272 - val_root_mean_squared_error: 1.0017
# Epoch 5/15
# 2814/2814 [==============================] - 17s 6ms/step - loss: 0.9868 - root_mean_squared_error: 0.9298 - val_loss: 1.1318 - val_root_mean_squared_error: 1.0055
# Epoch 6/15
# 2814/2814 [==============================] - 22s 8ms/step - loss: 0.9792 - root_mean_squared_error: 0.9292 - val_loss: 1.1138 - val_root_mean_squared_error: 1.0004
# Epoch 7/15
# 2814/2814 [==============================] - 21s 7ms/step - loss: 0.9739 - root_mean_squared_error: 0.9293 - val_loss: 1.1105 - val_root_mean_squared_error: 0.9998
# Epoch 8/15
# 2814/2814 [==============================] - 21s 8ms/step - loss: 0.9703 - root_mean_squared_error: 0.9290 - val_loss: 1.1049 - val_root_mean_squared_error: 1.0008
# Epoch 9/15
# 2814/2814 [==============================] - 22s 8ms/step - loss: 0.9674 - root_mean_squared_error: 0.9289 - val_loss: 1.1031 - val_root_mean_squared_error: 1.0001
# Epoch 10/15
# 2814/2814 [==============================] - 22s 8ms/step - loss: 0.9652 - root_mean_squared_error: 0.9290 - val_loss: 1.1009 - val_root_mean_squared_error: 0.9999
# Epoch 11/15
# 2814/2814 [==============================] - 21s 7ms/step - loss: 0.9623 - root_mean_squared_error: 0.9289 - val_loss: 1.0997 - val_root_mean_squared_error: 1.0008
# Epoch 12/15
# 2814/2814 [==============================] - 19s 7ms/step - loss: 0.9596 - root_mean_squared_error: 0.9288 - val_loss: 1.0956 - val_root_mean_squared_error: 1.0006
# Epoch 13/15
# 2814/2814 [==============================] - 21s 7ms/step - loss: 0.9592 - root_mean_squared_error: 0.9290 - val_loss: 1.1145 - val_root_mean_squared_error: 1.0063
# Epoch 14/15
# 2814/2814 [==============================] - 21s 8ms/step - loss: 0.9575 - root_mean_squared_error: 0.9289 - val_loss: 1.0911 - val_root_mean_squared_error: 1.0001
# Epoch 15/15
# 2814/2814 [==============================] - 21s 8ms/step - loss: 0.9557 - root_mean_squared_error: 0.9289 - val_loss: 1.0989 - val_root_mean_squared_error: 1.0030
# Epoch 1/15
# 2814/2814 [==============================] - 20s 7ms/step - loss: 4.1557 - root_mean_squared_error: 1.6838 - val_loss: 2.4853 - val_root_mean_squared_error: 1.3562
# Epoch 2/15
# 2814/2814 [==============================] - 20s 7ms/step - loss: 1.3505 - root_mean_squared_error: 1.0013 - val_loss: 1.2691 - val_root_mean_squared_error: 1.0471
# Epoch 3/15
# 2814/2814 [==============================] - 16s 6ms/step - loss: 1.0558 - root_mean_squared_error: 0.9635 - val_loss: 1.1507 - val_root_mean_squared_error: 1.0197
# Epoch 4/15
# 2814/2814 [==============================] - 19s 7ms/step - loss: 1.0335 - root_mean_squared_error: 0.9610 - val_loss: 1.1428 - val_root_mean_squared_error: 1.0168
# Epoch 5/15
# 2814/2814 [==============================] - 19s 7ms/step - loss: 1.0332 - root_mean_squared_error: 0.9610 - val_loss: 1.1463 - val_root_mean_squared_error: 1.0192
# Epoch 6/15
# 2814/2814 [==============================] - 24s 9ms/step - loss: 1.0253 - root_mean_squared_error: 0.9586 - val_loss: 1.1374 - val_root_mean_squared_error: 1.0179
# Epoch 7/15
# 2814/2814 [==============================] - 27s 10ms/step - loss: 1.0051 - root_mean_squared_error: 0.9527 - val_loss: 1.1176 - val_root_mean_squared_error: 1.0128
# Epoch 8/15
# 2814/2814 [==============================] - 29s 10ms/step - loss: 0.9813 - root_mean_squared_error: 0.9461 - val_loss: 1.1027 - val_root_mean_squared_error: 1.0102
# Epoch 9/15
# 2814/2814 [==============================] - 22s 8ms/step - loss: 0.9672 - root_mean_squared_error: 0.9426 - val_loss: 1.0954 - val_root_mean_squared_error: 1.0096
# Epoch 10/15
# 2814/2814 [==============================] - 16s 6ms/step - loss: 0.9617 - root_mean_squared_error: 0.9414 - val_loss: 1.0925 - val_root_mean_squared_error: 1.0094
# Epoch 11/15
# 2814/2814 [==============================] - 20s 7ms/step - loss: 0.9571 - root_mean_squared_error: 0.9399 - val_loss: 1.0868 - val_root_mean_squared_error: 1.0073
# Epoch 12/15
# 2814/2814 [==============================] - 20s 7ms/step - loss: 0.9503 - root_mean_squared_error: 0.9377 - val_loss: 1.0802 - val_root_mean_squared_error: 1.0057
# Epoch 13/15
# 2814/2814 [==============================] - 20s 7ms/step - loss: 0.9442 - root_mean_squared_error: 0.9363 - val_loss: 1.0784 - val_root_mean_squared_error: 1.0055
# Epoch 14/15
# 2814/2814 [==============================] - 20s 7ms/step - loss: 0.9397 - root_mean_squared_error: 0.9351 - val_loss: 1.0720 - val_root_mean_squared_error: 1.0043
# Epoch 15/15
# 2814/2814 [==============================] - 21s 8ms/step - loss: 0.9369 - root_mean_squared_error: 0.9345 - val_loss: 1.0720 - val_root_mean_squared_error: 1.0046
# Epoch 1/15
# 2814/2814 [==============================] - 20s 7ms/step - loss: 1.6082 - root_mean_squared_error: 1.1512 - val_loss: 1.2176 - val_root_mean_squared_error: 1.0238
# Epoch 2/15
# 2814/2814 [==============================] - 22s 8ms/step - loss: 1.0799 - root_mean_squared_error: 0.9607 - val_loss: 1.1703 - val_root_mean_squared_error: 1.0128
# Epoch 3/15
# 2814/2814 [==============================] - 22s 8ms/step - loss: 1.0183 - root_mean_squared_error: 0.9438 - val_loss: 1.1335 - val_root_mean_squared_error: 1.0057
# Epoch 4/15
# 2814/2814 [==============================] - 21s 7ms/step - loss: 0.9862 - root_mean_squared_error: 0.9344 - val_loss: 1.1264 - val_root_mean_squared_error: 1.0037
# Epoch 5/15
# 2814/2814 [==============================] - 21s 7ms/step - loss: 0.9747 - root_mean_squared_error: 0.9318 - val_loss: 1.0975 - val_root_mean_squared_error: 1.0001
# Epoch 6/15
# 2814/2814 [==============================] - 20s 7ms/step - loss: 0.9605 - root_mean_squared_error: 0.9290 - val_loss: 1.1090 - val_root_mean_squared_error: 1.0027
# Epoch 7/15
# 2814/2814 [==============================] - 21s 7ms/step - loss: 0.9574 - root_mean_squared_error: 0.9288 - val_loss: 1.1076 - val_root_mean_squared_error: 1.0030
# Epoch 8/15
# 2814/2814 [==============================] - 21s 7ms/step - loss: 0.9541 - root_mean_squared_error: 0.9283 - val_loss: 1.0885 - val_root_mean_squared_error: 1.0007
# Epoch 9/15
# 2814/2814 [==============================] - 17s 6ms/step - loss: 0.9521 - root_mean_squared_error: 0.9283 - val_loss: 1.0847 - val_root_mean_squared_error: 1.0004
# Epoch 10/15
# 2814/2814 [==============================] - 20s 7ms/step - loss: 0.9522 - root_mean_squared_error: 0.9288 - val_loss: 1.0883 - val_root_mean_squared_error: 0.9989
# Epoch 11/15
# 2814/2814 [==============================] - 21s 7ms/step - loss: 0.9506 - root_mean_squared_error: 0.9284 - val_loss: 1.0988 - val_root_mean_squared_error: 1.0001
# Epoch 12/15
# 2814/2814 [==============================] - 20s 7ms/step - loss: 0.9500 - root_mean_squared_error: 0.9285 - val_loss: 1.0855 - val_root_mean_squared_error: 1.0011
# Epoch 13/15
# 2814/2814 [==============================] - 19s 7ms/step - loss: 0.9502 - root_mean_squared_error: 0.9286 - val_loss: 1.0986 - val_root_mean_squared_error: 1.0029
# Epoch 14/15
# 2814/2814 [==============================] - 19s 7ms/step - loss: 0.9502 - root_mean_squared_error: 0.9289 - val_loss: 1.0969 - val_root_mean_squared_error: 1.0014
# Epoch 15/15
# 2814/2814 [==============================] - 19s 7ms/step - loss: 0.9486 - root_mean_squared_error: 0.9285 - val_loss: 1.0924 - val_root_mean_squared_error: 0.9993
# Epoch 1/15
# 2814/2814 [==============================] - 21s 7ms/step - loss: 1.4750 - root_mean_squared_error: 1.0880 - val_loss: 1.2404 - val_root_mean_squared_error: 1.0213
# Epoch 2/15
# 2814/2814 [==============================] - 20s 7ms/step - loss: 1.0798 - root_mean_squared_error: 0.9498 - val_loss: 1.1793 - val_root_mean_squared_error: 1.0076
# Epoch 3/15
# 2814/2814 [==============================] - 20s 7ms/step - loss: 1.0339 - root_mean_squared_error: 0.9385 - val_loss: 1.1644 - val_root_mean_squared_error: 1.0074
# Epoch 4/15
# 2814/2814 [==============================] - 20s 7ms/step - loss: 1.0081 - root_mean_squared_error: 0.9325 - val_loss: 1.1375 - val_root_mean_squared_error: 1.0007
# Epoch 5/15
# 2814/2814 [==============================] - 20s 7ms/step - loss: 0.9930 - root_mean_squared_error: 0.9301 - val_loss: 1.1337 - val_root_mean_squared_error: 1.0048
# Epoch 6/15
# 2814/2814 [==============================] - 17s 6ms/step - loss: 0.9883 - root_mean_squared_error: 0.9296 - val_loss: 1.1326 - val_root_mean_squared_error: 1.0045
# Epoch 7/15
# 2814/2814 [==============================] - 20s 7ms/step - loss: 0.9814 - root_mean_squared_error: 0.9293 - val_loss: 1.1126 - val_root_mean_squared_error: 1.0005
# Epoch 8/15
# 2814/2814 [==============================] - 20s 7ms/step - loss: 0.9777 - root_mean_squared_error: 0.9290 - val_loss: 1.1107 - val_root_mean_squared_error: 1.0003
# Epoch 9/15
# 2814/2814 [==============================] - 20s 7ms/step - loss: 0.9738 - root_mean_squared_error: 0.9292 - val_loss: 1.1136 - val_root_mean_squared_error: 1.0032
# Epoch 10/15
# 2814/2814 [==============================] - 21s 7ms/step - loss: 0.9721 - root_mean_squared_error: 0.9290 - val_loss: 1.1070 - val_root_mean_squared_error: 1.0001
# Epoch 11/15
# 2814/2814 [==============================] - 20s 7ms/step - loss: 0.9686 - root_mean_squared_error: 0.9289 - val_loss: 1.1095 - val_root_mean_squared_error: 1.0053
# Epoch 12/15
# 2814/2814 [==============================] - 20s 7ms/step - loss: 0.9667 - root_mean_squared_error: 0.9290 - val_loss: 1.1126 - val_root_mean_squared_error: 1.0013
# Epoch 13/15
# 2814/2814 [==============================] - 17s 6ms/step - loss: 0.9655 - root_mean_squared_error: 0.9285 - val_loss: 1.1097 - val_root_mean_squared_error: 0.9996
# Epoch 14/15
# 2814/2814 [==============================] - 20s 7ms/step - loss: 0.9628 - root_mean_squared_error: 0.9289 - val_loss: 1.0957 - val_root_mean_squared_error: 1.0001
# Epoch 15/15
# 2814/2814 [==============================] - 20s 7ms/step - loss: 0.9624 - root_mean_squared_error: 0.9289 - val_loss: 1.1039 - val_root_mean_squared_error: 1.0004
# Epoch 1/15
# 2814/2814 [==============================] - 19s 6ms/step - loss: 3.8062 - root_mean_squared_error: 1.5826 - val_loss: 2.4122 - val_root_mean_squared_error: 1.3447
# Epoch 2/15
# 2814/2814 [==============================] - 18s 7ms/step - loss: 1.3780 - root_mean_squared_error: 1.0164 - val_loss: 1.3049 - val_root_mean_squared_error: 1.0576
# Epoch 3/15
# 2814/2814 [==============================] - 15s 5ms/step - loss: 1.0977 - root_mean_squared_error: 0.9774 - val_loss: 1.1741 - val_root_mean_squared_error: 1.0246
# Epoch 4/15
# 2814/2814 [==============================] - 18s 7ms/step - loss: 1.0728 - root_mean_squared_error: 0.9713 - val_loss: 1.1791 - val_root_mean_squared_error: 1.0242
# Epoch 5/15
# 2814/2814 [==============================] - 18s 7ms/step - loss: 1.0619 - root_mean_squared_error: 0.9678 - val_loss: 1.1577 - val_root_mean_squared_error: 1.0204
# Epoch 6/15
# 2814/2814 [==============================] - 19s 7ms/step - loss: 1.0237 - root_mean_squared_error: 0.9574 - val_loss: 1.1273 - val_root_mean_squared_error: 1.0154
# Epoch 7/15
# 2814/2814 [==============================] - 19s 7ms/step - loss: 0.9942 - root_mean_squared_error: 0.9499 - val_loss: 1.1122 - val_root_mean_squared_error: 1.0131
# Epoch 8/15
# 2814/2814 [==============================] - 19s 7ms/step - loss: 0.9810 - root_mean_squared_error: 0.9466 - val_loss: 1.1038 - val_root_mean_squared_error: 1.0103
# Epoch 9/15
# 2814/2814 [==============================] - 18s 7ms/step - loss: 0.9745 - root_mean_squared_error: 0.9446 - val_loss: 1.1038 - val_root_mean_squared_error: 1.0104
# Epoch 10/15
# 2814/2814 [==============================] - 15s 5ms/step - loss: 0.9676 - root_mean_squared_error: 0.9426 - val_loss: 1.0930 - val_root_mean_squared_error: 1.0077
# Epoch 11/15
# 2814/2814 [==============================] - 18s 7ms/step - loss: 0.9610 - root_mean_squared_error: 0.9405 - val_loss: 1.0908 - val_root_mean_squared_error: 1.0066
# Epoch 12/15
# 2814/2814 [==============================] - 18s 7ms/step - loss: 0.9557 - root_mean_squared_error: 0.9390 - val_loss: 1.0843 - val_root_mean_squared_error: 1.0072
# Epoch 13/15
# 2814/2814 [==============================] - 18s 7ms/step - loss: 0.9480 - root_mean_squared_error: 0.9370 - val_loss: 1.0812 - val_root_mean_squared_error: 1.0067
# Epoch 14/15
# 2814/2814 [==============================] - 18s 6ms/step - loss: 0.9435 - root_mean_squared_error: 0.9355 - val_loss: 1.0752 - val_root_mean_squared_error: 1.0049
# Epoch 15/15
# 2814/2814 [==============================] - 18s 6ms/step - loss: 0.9394 - root_mean_squared_error: 0.9348 - val_loss: 1.0716 - val_root_mean_squared_error: 1.0038
# Epoch 1/15
# 2814/2814 [==============================] - 17s 6ms/step - loss: 1.6299 - root_mean_squared_error: 1.1405 - val_loss: 1.2330 - val_root_mean_squared_error: 1.0293
# Epoch 2/15
# 2814/2814 [==============================] - 20s 7ms/step - loss: 1.0823 - root_mean_squared_error: 0.9612 - val_loss: 1.1584 - val_root_mean_squared_error: 1.0111
# Epoch 3/15
# 2814/2814 [==============================] - 19s 7ms/step - loss: 1.0054 - root_mean_squared_error: 0.9373 - val_loss: 1.1254 - val_root_mean_squared_error: 1.0027
# Epoch 4/15
# 2814/2814 [==============================] - 20s 7ms/step - loss: 0.9834 - root_mean_squared_error: 0.9310 - val_loss: 1.1117 - val_root_mean_squared_error: 1.0009
# Epoch 5/15
# 2814/2814 [==============================] - 19s 7ms/step - loss: 0.9738 - root_mean_squared_error: 0.9296 - val_loss: 1.1123 - val_root_mean_squared_error: 1.0046
# Epoch 6/15
# 2814/2814 [==============================] - 20s 7ms/step - loss: 0.9689 - root_mean_squared_error: 0.9292 - val_loss: 1.1109 - val_root_mean_squared_error: 1.0011
# Epoch 7/15
# 2814/2814 [==============================] - 18s 7ms/step - loss: 0.9660 - root_mean_squared_error: 0.9288 - val_loss: 1.0947 - val_root_mean_squared_error: 1.0010
# Epoch 8/15
# 2814/2814 [==============================] - 20s 7ms/step - loss: 0.9637 - root_mean_squared_error: 0.9287 - val_loss: 1.1140 - val_root_mean_squared_error: 1.0028
# Epoch 9/15
# 2814/2814 [==============================] - 20s 7ms/step - loss: 0.9637 - root_mean_squared_error: 0.9286 - val_loss: 1.1283 - val_root_mean_squared_error: 1.0013
# Epoch 10/15
# 2814/2814 [==============================] - 21s 7ms/step - loss: 0.9598 - root_mean_squared_error: 0.9286 - val_loss: 1.0934 - val_root_mean_squared_error: 1.0036
# Epoch 11/15
# 2814/2814 [==============================] - 20s 7ms/step - loss: 0.9610 - root_mean_squared_error: 0.9288 - val_loss: 1.1032 - val_root_mean_squared_error: 1.0017
# Epoch 12/15
# 2814/2814 [==============================] - 20s 7ms/step - loss: 0.9606 - root_mean_squared_error: 0.9286 - val_loss: 1.1148 - val_root_mean_squared_error: 1.0046
# Epoch 13/15
# 2814/2814 [==============================] - 20s 7ms/step - loss: 0.9603 - root_mean_squared_error: 0.9288 - val_loss: 1.1118 - val_root_mean_squared_error: 1.0016
# Epoch 14/15
# 2814/2814 [==============================] - 16s 6ms/step - loss: 0.9596 - root_mean_squared_error: 0.9287 - val_loss: 1.1034 - val_root_mean_squared_error: 1.0049
# Epoch 15/15
# 2814/2814 [==============================] - 20s 7ms/step - loss: 0.9603 - root_mean_squared_error: 0.9290 - val_loss: 1.1058 - val_root_mean_squared_error: 1.0032
# Epoch 1/15
# 2814/2814 [==============================] - 22s 7ms/step - loss: 1.4988 - root_mean_squared_error: 1.0912 - val_loss: 1.2377 - val_root_mean_squared_error: 1.0184
# Epoch 2/15
# 2814/2814 [==============================] - 20s 7ms/step - loss: 1.0766 - root_mean_squared_error: 0.9480 - val_loss: 1.1804 - val_root_mean_squared_error: 1.0098
# Epoch 3/15
# 2814/2814 [==============================] - 21s 7ms/step - loss: 1.0387 - root_mean_squared_error: 0.9384 - val_loss: 1.1572 - val_root_mean_squared_error: 1.0056
# Epoch 4/15
# 2814/2814 [==============================] - 17s 6ms/step - loss: 1.0192 - root_mean_squared_error: 0.9349 - val_loss: 1.1421 - val_root_mean_squared_error: 1.0035
# Epoch 5/15
# 2814/2814 [==============================] - 20s 7ms/step - loss: 1.0042 - root_mean_squared_error: 0.9320 - val_loss: 1.1290 - val_root_mean_squared_error: 1.0036
# Epoch 6/15
# 2814/2814 [==============================] - 21s 7ms/step - loss: 0.9914 - root_mean_squared_error: 0.9296 - val_loss: 1.1263 - val_root_mean_squared_error: 1.0013
# Epoch 7/15
# 2814/2814 [==============================] - 20s 7ms/step - loss: 0.9869 - root_mean_squared_error: 0.9292 - val_loss: 1.1210 - val_root_mean_squared_error: 1.0007
# Epoch 8/15
# 2814/2814 [==============================] - 20s 7ms/step - loss: 0.9809 - root_mean_squared_error: 0.9289 - val_loss: 1.1335 - val_root_mean_squared_error: 1.0057
# Epoch 9/15
# 2814/2814 [==============================] - 21s 7ms/step - loss: 0.9815 - root_mean_squared_error: 0.9289 - val_loss: 1.1205 - val_root_mean_squared_error: 1.0013
# Epoch 10/15
# 2814/2814 [==============================] - 20s 7ms/step - loss: 0.9771 - root_mean_squared_error: 0.9289 - val_loss: 1.1201 - val_root_mean_squared_error: 1.0031
# Epoch 11/15
# 2814/2814 [==============================] - 18s 6ms/step - loss: 0.9768 - root_mean_squared_error: 0.9289 - val_loss: 1.1091 - val_root_mean_squared_error: 1.0000
# Epoch 12/15
# 2814/2814 [==============================] - 20s 7ms/step - loss: 0.9736 - root_mean_squared_error: 0.9287 - val_loss: 1.1102 - val_root_mean_squared_error: 1.0017
# Epoch 13/15
# 2814/2814 [==============================] - 20s 7ms/step - loss: 0.9724 - root_mean_squared_error: 0.9291 - val_loss: 1.1146 - val_root_mean_squared_error: 1.0003
# Epoch 14/15
# 2814/2814 [==============================] - 20s 7ms/step - loss: 0.9709 - root_mean_squared_error: 0.9288 - val_loss: 1.1031 - val_root_mean_squared_error: 0.9994
# Epoch 15/15
# 2814/2814 [==============================] - 20s 7ms/step - loss: 0.9669 - root_mean_squared_error: 0.9287 - val_loss: 1.1035 - val_root_mean_squared_error: 1.0007
# Epoch 1/15
# 2814/2814 [==============================] - 16s 6ms/step - loss: 3.4765 - root_mean_squared_error: 1.4868 - val_loss: 2.3493 - val_root_mean_squared_error: 1.3287
# Epoch 2/15
# 2814/2814 [==============================] - 19s 7ms/step - loss: 1.4413 - root_mean_squared_error: 1.0436 - val_loss: 1.3396 - val_root_mean_squared_error: 1.0631
# Epoch 3/15
# 2814/2814 [==============================] - 20s 7ms/step - loss: 1.1409 - root_mean_squared_error: 0.9894 - val_loss: 1.2081 - val_root_mean_squared_error: 1.0281
# Epoch 4/15
# 2814/2814 [==============================] - 21s 7ms/step - loss: 1.1067 - root_mean_squared_error: 0.9787 - val_loss: 1.1995 - val_root_mean_squared_error: 1.0281
# Epoch 5/15
# 2814/2814 [==============================] - 21s 8ms/step - loss: 1.0623 - root_mean_squared_error: 0.9679 - val_loss: 1.1581 - val_root_mean_squared_error: 1.0216
# Epoch 6/15
# 2814/2814 [==============================] - 20s 7ms/step - loss: 1.0244 - root_mean_squared_error: 0.9577 - val_loss: 1.1345 - val_root_mean_squared_error: 1.0166
# Epoch 7/15
# 2814/2814 [==============================] - 18s 6ms/step - loss: 1.0033 - root_mean_squared_error: 0.9517 - val_loss: 1.1220 - val_root_mean_squared_error: 1.0120
# Epoch 8/15
# 2814/2814 [==============================] - 21s 7ms/step - loss: 0.9885 - root_mean_squared_error: 0.9471 - val_loss: 1.1085 - val_root_mean_squared_error: 1.0121
# Epoch 9/15
# 2814/2814 [==============================] - 22s 8ms/step - loss: 0.9761 - root_mean_squared_error: 0.9442 - val_loss: 1.0978 - val_root_mean_squared_error: 1.0091
# Epoch 10/15
# 2814/2814 [==============================] - 19s 7ms/step - loss: 0.9682 - root_mean_squared_error: 0.9423 - val_loss: 1.1035 - val_root_mean_squared_error: 1.0100
# Epoch 11/15
# 2814/2814 [==============================] - 21s 7ms/step - loss: 0.9632 - root_mean_squared_error: 0.9404 - val_loss: 1.0903 - val_root_mean_squared_error: 1.0080
# Epoch 12/15
# 2814/2814 [==============================] - 21s 7ms/step - loss: 0.9560 - root_mean_squared_error: 0.9381 - val_loss: 1.0859 - val_root_mean_squared_error: 1.0061
# Epoch 13/15
# 2814/2814 [==============================] - 22s 8ms/step - loss: 0.9483 - root_mean_squared_error: 0.9357 - val_loss: 1.0780 - val_root_mean_squared_error: 1.0047
# Epoch 14/15
# 2814/2814 [==============================] - 18s 7ms/step - loss: 0.9422 - root_mean_squared_error: 0.9347 - val_loss: 1.0741 - val_root_mean_squared_error: 1.0046
# Epoch 15/15
# 2814/2814 [==============================] - 19s 7ms/step - loss: 0.9390 - root_mean_squared_error: 0.9344 - val_loss: 1.0791 - val_root_mean_squared_error: 1.0042
# Epoch 1/15
# 2814/2814 [==============================] - 21s 7ms/step - loss: 1.6400 - root_mean_squared_error: 1.1347 - val_loss: 1.2429 - val_root_mean_squared_error: 1.0304
# Epoch 2/15
# 2814/2814 [==============================] - 20s 7ms/step - loss: 1.0928 - root_mean_squared_error: 0.9646 - val_loss: 1.1720 - val_root_mean_squared_error: 1.0149
# Epoch 3/15
# 2814/2814 [==============================] - 20s 7ms/step - loss: 1.0261 - root_mean_squared_error: 0.9419 - val_loss: 1.1521 - val_root_mean_squared_error: 1.0037
# Epoch 4/15
# 2814/2814 [==============================] - 17s 6ms/step - loss: 0.9938 - root_mean_squared_error: 0.9316 - val_loss: 1.1222 - val_root_mean_squared_error: 1.0020
# Epoch 5/15
# 2814/2814 [==============================] - 20s 7ms/step - loss: 0.9835 - root_mean_squared_error: 0.9299 - val_loss: 1.1170 - val_root_mean_squared_error: 1.0018
# Epoch 6/15
# 2814/2814 [==============================] - 19s 7ms/step - loss: 0.9802 - root_mean_squared_error: 0.9290 - val_loss: 1.1228 - val_root_mean_squared_error: 1.0004
# Epoch 7/15
# 2814/2814 [==============================] - 20s 7ms/step - loss: 0.9775 - root_mean_squared_error: 0.9288 - val_loss: 1.1099 - val_root_mean_squared_error: 1.0016
# Epoch 8/15
# 2814/2814 [==============================] - 20s 7ms/step - loss: 0.9789 - root_mean_squared_error: 0.9286 - val_loss: 1.1127 - val_root_mean_squared_error: 1.0024
# Epoch 9/15
# 2814/2814 [==============================] - 19s 7ms/step - loss: 0.9767 - root_mean_squared_error: 0.9290 - val_loss: 1.1309 - val_root_mean_squared_error: 1.0000
# Epoch 10/15
# 2814/2814 [==============================] - 17s 6ms/step - loss: 0.9756 - root_mean_squared_error: 0.9287 - val_loss: 1.1229 - val_root_mean_squared_error: 1.0023
# Epoch 11/15
# 2814/2814 [==============================] - 18s 7ms/step - loss: 0.9750 - root_mean_squared_error: 0.9288 - val_loss: 1.1053 - val_root_mean_squared_error: 1.0019
# Epoch 12/15
# 2814/2814 [==============================] - 19s 7ms/step - loss: 0.9772 - root_mean_squared_error: 0.9291 - val_loss: 1.0963 - val_root_mean_squared_error: 1.0012
# Epoch 13/15
# 2814/2814 [==============================] - 19s 7ms/step - loss: 0.9773 - root_mean_squared_error: 0.9289 - val_loss: 1.1220 - val_root_mean_squared_error: 1.0006
# Epoch 14/15
# 2814/2814 [==============================] - 19s 7ms/step - loss: 0.9763 - root_mean_squared_error: 0.9291 - val_loss: 1.1292 - val_root_mean_squared_error: 1.0015
# Epoch 15/15
# 2814/2814 [==============================] - 19s 7ms/step - loss: 0.9797 - root_mean_squared_error: 0.9291 - val_loss: 1.1129 - val_root_mean_squared_error: 1.0018
# Epoch 1/15
# 2814/2814 [==============================] - 20s 7ms/step - loss: 1.5077 - root_mean_squared_error: 1.0852 - val_loss: 1.2380 - val_root_mean_squared_error: 1.0186
# Epoch 2/15
# 2814/2814 [==============================] - 22s 8ms/step - loss: 1.0810 - root_mean_squared_error: 0.9478 - val_loss: 1.1973 - val_root_mean_squared_error: 1.0110
# Epoch 3/15
# 2814/2814 [==============================] - 23s 8ms/step - loss: 1.0373 - root_mean_squared_error: 0.9344 - val_loss: 1.1565 - val_root_mean_squared_error: 1.0041
# Epoch 4/15
# 2814/2814 [==============================] - 23s 8ms/step - loss: 1.0186 - root_mean_squared_error: 0.9311 - val_loss: 1.1513 - val_root_mean_squared_error: 1.0048
# Epoch 5/15
# 2814/2814 [==============================] - 23s 8ms/step - loss: 1.0089 - root_mean_squared_error: 0.9301 - val_loss: 1.1376 - val_root_mean_squared_error: 1.0012
# Epoch 6/15
# 2814/2814 [==============================] - 20s 7ms/step - loss: 1.0025 - root_mean_squared_error: 0.9296 - val_loss: 1.1390 - val_root_mean_squared_error: 0.9999
# Epoch 7/15
# 2814/2814 [==============================] - 17s 6ms/step - loss: 0.9994 - root_mean_squared_error: 0.9295 - val_loss: 1.1396 - val_root_mean_squared_error: 1.0007
# Epoch 8/15
# 2814/2814 [==============================] - 20s 7ms/step - loss: 0.9927 - root_mean_squared_error: 0.9293 - val_loss: 1.1406 - val_root_mean_squared_error: 1.0023
# Epoch 9/15
# 2814/2814 [==============================] - 24s 9ms/step - loss: 0.9903 - root_mean_squared_error: 0.9293 - val_loss: 1.1125 - val_root_mean_squared_error: 0.9995
# Epoch 10/15
# 2814/2814 [==============================] - 20s 7ms/step - loss: 0.9864 - root_mean_squared_error: 0.9291 - val_loss: 1.1262 - val_root_mean_squared_error: 1.0006
# Epoch 11/15
# 2814/2814 [==============================] - 20s 7ms/step - loss: 0.9858 - root_mean_squared_error: 0.9291 - val_loss: 1.1128 - val_root_mean_squared_error: 1.0010
# Epoch 12/15
# 2814/2814 [==============================] - 20s 7ms/step - loss: 0.9785 - root_mean_squared_error: 0.9286 - val_loss: 1.1309 - val_root_mean_squared_error: 1.0032
# Epoch 13/15
# 2814/2814 [==============================] - 17s 6ms/step - loss: 0.9809 - root_mean_squared_error: 0.9288 - val_loss: 1.1388 - val_root_mean_squared_error: 1.0023
# Epoch 14/15
# 2814/2814 [==============================] - 20s 7ms/step - loss: 0.9771 - root_mean_squared_error: 0.9289 - val_loss: 1.1299 - val_root_mean_squared_error: 1.0023
# Epoch 15/15
# 2814/2814 [==============================] - 21s 7ms/step - loss: 0.9746 - root_mean_squared_error: 0.9286 - val_loss: 1.1140 - val_root_mean_squared_error: 1.0031
# Epoch 1/15
# 2814/2814 [==============================] - 20s 7ms/step - loss: 3.3428 - root_mean_squared_error: 1.4483 - val_loss: 2.2935 - val_root_mean_squared_error: 1.3079
# Epoch 2/15
# 2814/2814 [==============================] - 19s 7ms/step - loss: 1.4954 - root_mean_squared_error: 1.0624 - val_loss: 1.3641 - val_root_mean_squared_error: 1.0668
# Epoch 3/15
# 2814/2814 [==============================] - 15s 5ms/step - loss: 1.1662 - root_mean_squared_error: 0.9943 - val_loss: 1.2389 - val_root_mean_squared_error: 1.0339
# Epoch 4/15
# 2814/2814 [==============================] - 19s 7ms/step - loss: 1.1147 - root_mean_squared_error: 0.9807 - val_loss: 1.1911 - val_root_mean_squared_error: 1.0282
# Epoch 5/15
# 2814/2814 [==============================] - 19s 7ms/step - loss: 1.0523 - root_mean_squared_error: 0.9653 - val_loss: 1.1528 - val_root_mean_squared_error: 1.0203
# Epoch 6/15
# 2814/2814 [==============================] - 19s 7ms/step - loss: 1.0180 - root_mean_squared_error: 0.9555 - val_loss: 1.1282 - val_root_mean_squared_error: 1.0141
# Epoch 7/15
# 2814/2814 [==============================] - 19s 7ms/step - loss: 0.9991 - root_mean_squared_error: 0.9500 - val_loss: 1.1221 - val_root_mean_squared_error: 1.0114
# Epoch 8/15
# 2814/2814 [==============================] - 19s 7ms/step - loss: 0.9862 - root_mean_squared_error: 0.9457 - val_loss: 1.1085 - val_root_mean_squared_error: 1.0102
# Epoch 9/15
# 2814/2814 [==============================] - 19s 7ms/step - loss: 0.9714 - root_mean_squared_error: 0.9412 - val_loss: 1.0953 - val_root_mean_squared_error: 1.0064
# Epoch 10/15
# 2814/2814 [==============================] - 16s 6ms/step - loss: 0.9606 - root_mean_squared_error: 0.9386 - val_loss: 1.0878 - val_root_mean_squared_error: 1.0065
# Epoch 11/15
# 2814/2814 [==============================] - 18s 6ms/step - loss: 0.9551 - root_mean_squared_error: 0.9374 - val_loss: 1.0830 - val_root_mean_squared_error: 1.0047
# Epoch 12/15
# 2814/2814 [==============================] - 19s 7ms/step - loss: 0.9487 - root_mean_squared_error: 0.9357 - val_loss: 1.0799 - val_root_mean_squared_error: 1.0046
# Epoch 13/15
# 2814/2814 [==============================] - 19s 7ms/step - loss: 0.9463 - root_mean_squared_error: 0.9350 - val_loss: 1.0736 - val_root_mean_squared_error: 1.0040
# Epoch 14/15
# 2814/2814 [==============================] - 19s 7ms/step - loss: 0.9443 - root_mean_squared_error: 0.9344 - val_loss: 1.0740 - val_root_mean_squared_error: 1.0035
# Epoch 15/15
# 2814/2814 [==============================] - 19s 7ms/step - loss: 0.9405 - root_mean_squared_error: 0.9331 - val_loss: 1.0761 - val_root_mean_squared_error: 1.0038
# Epoch 1/15
# 2814/2814 [==============================] - 18s 6ms/step - loss: 1.6562 - root_mean_squared_error: 1.1356 - val_loss: 1.2477 - val_root_mean_squared_error: 1.0319
# Epoch 2/15
# 2814/2814 [==============================] - 24s 8ms/step - loss: 1.0905 - root_mean_squared_error: 0.9628 - val_loss: 1.1815 - val_root_mean_squared_error: 1.0143
# Epoch 3/15
# 2814/2814 [==============================] - 25s 9ms/step - loss: 1.0360 - root_mean_squared_error: 0.9421 - val_loss: 1.1567 - val_root_mean_squared_error: 1.0034
# Epoch 4/15
# 2814/2814 [==============================] - 21s 7ms/step - loss: 1.0067 - root_mean_squared_error: 0.9334 - val_loss: 1.1700 - val_root_mean_squared_error: 1.0017
# Epoch 5/15
# 2814/2814 [==============================] - 24s 9ms/step - loss: 0.9984 - root_mean_squared_error: 0.9302 - val_loss: 1.1444 - val_root_mean_squared_error: 1.0007
# Epoch 6/15
# 2814/2814 [==============================] - 20s 7ms/step - loss: 0.9885 - root_mean_squared_error: 0.9291 - val_loss: 1.1451 - val_root_mean_squared_error: 1.0059
# Epoch 7/15
# 2814/2814 [==============================] - 22s 8ms/step - loss: 0.9918 - root_mean_squared_error: 0.9291 - val_loss: 1.1144 - val_root_mean_squared_error: 1.0052
# Epoch 8/15
# 2814/2814 [==============================] - 20s 7ms/step - loss: 0.9912 - root_mean_squared_error: 0.9290 - val_loss: 1.1457 - val_root_mean_squared_error: 1.0022
# Epoch 9/15
# 2814/2814 [==============================] - 21s 7ms/step - loss: 0.9888 - root_mean_squared_error: 0.9293 - val_loss: 1.1287 - val_root_mean_squared_error: 1.0001
# Epoch 10/15
# 2814/2814 [==============================] - 21s 8ms/step - loss: 0.9932 - root_mean_squared_error: 0.9294 - val_loss: 1.1180 - val_root_mean_squared_error: 1.0063
# Epoch 11/15
# 2814/2814 [==============================] - 22s 8ms/step - loss: 0.9904 - root_mean_squared_error: 0.9294 - val_loss: 1.1368 - val_root_mean_squared_error: 1.0002
# Epoch 12/15
# 2814/2814 [==============================] - 22s 8ms/step - loss: 0.9934 - root_mean_squared_error: 0.9295 - val_loss: 1.1375 - val_root_mean_squared_error: 1.0083
# Epoch 13/15
# 2814/2814 [==============================] - 19s 7ms/step - loss: 0.9951 - root_mean_squared_error: 0.9298 - val_loss: 1.1542 - val_root_mean_squared_error: 1.0056
# Epoch 14/15
# 2814/2814 [==============================] - 22s 8ms/step - loss: 0.9932 - root_mean_squared_error: 0.9295 - val_loss: 1.1261 - val_root_mean_squared_error: 1.0025
# Epoch 15/15
# 2814/2814 [==============================] - 22s 8ms/step - loss: 0.9956 - root_mean_squared_error: 0.9299 - val_loss: 1.1286 - val_root_mean_squared_error: 1.0025
# Epoch 1/15
# 2814/2814 [==============================] - 25s 8ms/step - loss: 1.5945 - root_mean_squared_error: 1.1143 - val_loss: 1.2544 - val_root_mean_squared_error: 1.0215
# Epoch 2/15
# 2814/2814 [==============================] - 22s 8ms/step - loss: 1.1002 - root_mean_squared_error: 0.9523 - val_loss: 1.2155 - val_root_mean_squared_error: 1.0143
# Epoch 3/15
# 2814/2814 [==============================] - 22s 8ms/step - loss: 1.0611 - root_mean_squared_error: 0.9392 - val_loss: 1.1896 - val_root_mean_squared_error: 1.0064
# Epoch 4/15
# 2814/2814 [==============================] - 20s 7ms/step - loss: 1.0353 - root_mean_squared_error: 0.9330 - val_loss: 1.1641 - val_root_mean_squared_error: 1.0033
# Epoch 5/15
# 2814/2814 [==============================] - 23s 8ms/step - loss: 1.0230 - root_mean_squared_error: 0.9304 - val_loss: 1.1513 - val_root_mean_squared_error: 1.0050
# Epoch 6/15
# 2814/2814 [==============================] - 22s 8ms/step - loss: 1.0116 - root_mean_squared_error: 0.9298 - val_loss: 1.1665 - val_root_mean_squared_error: 1.0052
# Epoch 7/15
# 2814/2814 [==============================] - 23s 8ms/step - loss: 1.0110 - root_mean_squared_error: 0.9295 - val_loss: 1.1527 - val_root_mean_squared_error: 1.0015
# Epoch 8/15
# 2814/2814 [==============================] - 23s 8ms/step - loss: 1.0057 - root_mean_squared_error: 0.9297 - val_loss: 1.1495 - val_root_mean_squared_error: 1.0009
# Epoch 9/15
# 2814/2814 [==============================] - 22s 8ms/step - loss: 1.0039 - root_mean_squared_error: 0.9293 - val_loss: 1.1515 - val_root_mean_squared_error: 1.0047
# Epoch 10/15
# 2814/2814 [==============================] - 22s 8ms/step - loss: 0.9983 - root_mean_squared_error: 0.9289 - val_loss: 1.1182 - val_root_mean_squared_error: 1.0019
# Epoch 11/15
# 2814/2814 [==============================] - 19s 7ms/step - loss: 0.9973 - root_mean_squared_error: 0.9291 - val_loss: 1.1292 - val_root_mean_squared_error: 1.0011
# Epoch 12/15
# 2814/2814 [==============================] - 22s 8ms/step - loss: 0.9976 - root_mean_squared_error: 0.9292 - val_loss: 1.1309 - val_root_mean_squared_error: 1.0028
# Epoch 13/15
# 2814/2814 [==============================] - 22s 8ms/step - loss: 0.9928 - root_mean_squared_error: 0.9289 - val_loss: 1.1353 - val_root_mean_squared_error: 1.0011
# Epoch 14/15
# 2814/2814 [==============================] - 22s 8ms/step - loss: 0.9910 - root_mean_squared_error: 0.9290 - val_loss: 1.1475 - val_root_mean_squared_error: 1.0003
# Epoch 15/15
# 2814/2814 [==============================] - 27s 9ms/step - loss: 0.9896 - root_mean_squared_error: 0.9293 - val_loss: 1.1131 - val_root_mean_squared_error: 1.0010

# %%
metrics_df = pd.DataFrame(metrics_list,columns = ['no of factors','no of hidden layers','rmse','precision','recall','ndcg'])

# %%
metrics_df.to_csv('all_metrics.csv')

# %%
model = load_model('models/emb_32/2/model.h5')
# Out:
# 2022-04-26 16:27:52.689332: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-04-26 16:27:57.617195: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9575 MB memory:  -> device: 0, name: NVIDIA RTX A4000, pci bus id: 0000:05:00.0, compute capability: 8.6
# 2022-04-26 16:27:57.618783: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 3652 MB memory:  -> device: 1, name: NVIDIA RTX A4000, pci bus id: 0000:08:00.0, compute capability: 8.6
# 2022-04-26 16:27:57.620070: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 102 MB memory:  -> device: 2, name: NVIDIA RTX A4000, pci bus id: 0000:09:00.0, compute capability: 8.6
# 2022-04-26 16:27:57.621356: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:3 with 297 MB memory:  -> device: 3, name: NVIDIA RTX A4000, pci bus id: 0000:84:00.0, compute capability: 8.6

# %%
model.summary()
# Out:
# Model: "model_7"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  user_input (InputLayer)        [(None, 1)]          0           []
#
#  product_input (InputLayer)     [(None, 1)]          0           []
#
#  embedding_30 (Embedding)       (None, 1, 32)        193280      ['user_input[0][0]']
#
#  embedding_31 (Embedding)       (None, 1, 32)        118592      ['product_input[0][0]']
#
#  embedding_28 (Embedding)       (None, 1, 32)        193280      ['user_input[0][0]']
#
#  embedding_29 (Embedding)       (None, 1, 32)        118592      ['product_input[0][0]']
#
#  flatten_30 (Flatten)           (None, 32)           0           ['embedding_30[0][0]']
#
#  flatten_31 (Flatten)           (None, 32)           0           ['embedding_31[0][0]']
#
#  flatten_28 (Flatten)           (None, 32)           0           ['embedding_28[0][0]']
#
#  flatten_29 (Flatten)           (None, 32)           0           ['embedding_29[0][0]']
#
#  concatenate_14 (Concatenate)   (None, 64)           0           ['flatten_30[0][0]',
#                                                                   'flatten_31[0][0]']
#
#  multiply_7 (Multiply)          (None, 32)           0           ['flatten_28[0][0]',
#                                                                   'flatten_29[0][0]']
#
#  dense_13 (Dense)               (None, 64)           4160        ['concatenate_14[0][0]']
#
#  concatenate_15 (Concatenate)   (None, 96)           0           ['multiply_7[0][0]',
#                                                                   'dense_13[0][0]']
#
#  dense_14 (Dense)               (None, 1)            97          ['concatenate_15[0][0]']
#
# ==================================================================================================
# Total params: 628,001
# Trainable params: 628,001
# Non-trainable params: 0
# __________________________________________________________________________________________________
